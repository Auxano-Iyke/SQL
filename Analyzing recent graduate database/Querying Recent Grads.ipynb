# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline

db = 'jobs.db'

def run_query(q):
    with sqlite3.connect(db) as conn:
        return pd.read_sql(q,conn)

    
def run_command(c):
    with sqlite3.connect(db) as conn:
        conn.isolate_level = None
        conn.execute(c)
        
def show_table():
    q= '''
    SELECT 
        name,
        type
    FROM sqlite_master
    WHERE type IN("table","view")
    '''
    return run_query(q)

show_table()
# Out:
#            name   type
# 0  recent_grads  table

# %%
first_5 = 'SELECT * FROM recent_grads LIMIT 5'
run_query(first_5)
# Out:
#    index  Rank  Major_code                                      Major  \
# 0      0     1        2419                      PETROLEUM ENGINEERING
# 1      1     2        2416             MINING AND MINERAL ENGINEERING
# 2      2     3        2415                  METALLURGICAL ENGINEERING
# 3      3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      4     5        2405                       CHEMICAL ENGINEERING
#
#   Major_category  Total  Sample_size    Men  Women  ShareWomen      ...        \
# 0    Engineering   2339           36   2057    282    0.120564      ...
# 1    Engineering    756            7    679     77    0.101852      ...
# 2    Engineering    856            3    725    131    0.153037      ...
# 3    Engineering   1258           16   1123    135    0.107313      ...
# 4    Engineering  32260          289  21239  11021    0.341631      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0        270                  1207          37           0.018381  110000
# 1        170                   388          85           0.117241   75000
# 2        133                   340          16           0.024096   73000
# 3        150                   692          40           0.050125   70000
# 4       5180                 16697        1672           0.061098   65000
#
#    P25th   P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 0  95000  125000          1534               364            193
# 1  55000   90000           350               257             50
# 2  50000  105000           456               176              0
# 3  43000   80000           529               102              0
# 4  50000   75000         18314              4440            972
#
# [5 rows x 22 columns]

# %%
# First 10 rows

first_10 = 'SELECT * FROM recent_grads LIMIT 10'
run_query(first_10)
# Out:
#    index  Rank  Major_code                                      Major  \
# 0      0     1        2419                      PETROLEUM ENGINEERING
# 1      1     2        2416             MINING AND MINERAL ENGINEERING
# 2      2     3        2415                  METALLURGICAL ENGINEERING
# 3      3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      4     5        2405                       CHEMICAL ENGINEERING
# 5      5     6        2418                        NUCLEAR ENGINEERING
# 6      6     7        6202                          ACTUARIAL SCIENCE
# 7      7     8        5001                 ASTRONOMY AND ASTROPHYSICS
# 8      8     9        2414                     MECHANICAL ENGINEERING
# 9      9    10        2408                     ELECTRICAL ENGINEERING
#
#       Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# 0        Engineering   2339           36   2057    282    0.120564
# 1        Engineering    756            7    679     77    0.101852
# 2        Engineering    856            3    725    131    0.153037
# 3        Engineering   1258           16   1123    135    0.107313
# 4        Engineering  32260          289  21239  11021    0.341631
# 5        Engineering   2573           17   2200    373    0.144967
# 6           Business   3777           51    832    960    0.535714
# 7  Physical Sciences   1792           10   2110   1667    0.441356
# 8        Engineering  91227         1029  12953   2105    0.139793
# 9        Engineering  81527          631   8407   6548    0.437847
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# 0      ...              270                  1207          37
# 1      ...              170                   388          85
# 2      ...              133                   340          16
# 3      ...              150                   692          40
# 4      ...             5180                 16697        1672
# 5      ...              264                  1449         400
# 6      ...              296                  2482         308
# 7      ...              553                   827          33
# 8      ...            13101                 54639        4650
# 9      ...            12695                 41413        3895
#
#    Unemployment_rate  Median  P25th   P75th  College_jobs  Non_college_jobs  \
# 0           0.018381  110000  95000  125000          1534               364
# 1           0.117241   75000  55000   90000           350               257
# 2           0.024096   73000  50000  105000           456               176
# 3           0.050125   70000  43000   80000           529               102
# 4           0.061098   65000  50000   75000         18314              4440
# 5           0.177226   65000  50000  102000          1142               657
# 6           0.095652   62000  53000   72000          1768               314
# 7           0.021167   62000  31500  109000           972               500
# 8           0.057342   60000  48000   70000         52844             16384
# 9           0.059174   60000  45000   72000         45829             10874
#
#    Low_wage_jobs
# 0            193
# 1             50
# 2              0
# 3              0
# 4            972
# 5            244
# 6            259
# 7            220
# 8           3253
# 9           3170
#
# [10 rows x 22 columns]

# %%
# Majors with ShareWomen > 0.5
sw_5 = 'SELECT Major FROM recent_grads WHERE ShareWomen >= 0.5 LIMIT 5'
run_query(sw_5)
# Out:
#                                 Major
# 0                   ACTUARIAL SCIENCE
# 1                    COMPUTER SCIENCE
# 2           ENVIRONMENTAL ENGINEERING
# 3                             NURSING
# 4  INDUSTRIAL PRODUCTION TECHNOLOGIES

# %%
# Select majors with women in the minority.
min_women = '''SELECT Major,ShareWomen from recent_grads WHERE 
               ShareWomen <= 0.5 LIMIT 5'''
run_query(min_women)
# Out:
#                                        Major  ShareWomen
# 0                      PETROLEUM ENGINEERING    0.120564
# 1             MINING AND MINERAL ENGINEERING    0.101852
# 2                  METALLURGICAL ENGINEERING    0.153037
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING    0.107313
# 4                       CHEMICAL ENGINEERING    0.341631

# %%
# majors with female majority and median salary > 5000
f_med = '''SELECT Major, Major_Category,Median, ShareWomen FROM recent_grads
           WHERE ShareWomen >= 0.5 AND Median > 50000;'''
run_query(f_med)
# Out:
#                Major           Major_category  Median  ShareWomen
# 0  ACTUARIAL SCIENCE                 Business   62000    0.535714
# 1   COMPUTER SCIENCE  Computers & Mathematics   53000    0.578766

# %%
# median >= 10000 OR unemployed people <= 1000
med_une = '''SELECT Major, Median, Unemployed FROM recent_grads
             WHERE Median >= 10000 OR Unemployed <= 1000
             LIMIT 20;'''

run_query(med_une)
# Out:
#                                         Major  Median  Unemployed
# 0                       PETROLEUM ENGINEERING  110000          37
# 1              MINING AND MINERAL ENGINEERING   75000          85
# 2                   METALLURGICAL ENGINEERING   73000          16
# 3   NAVAL ARCHITECTURE AND MARINE ENGINEERING   70000          40
# 4                        CHEMICAL ENGINEERING   65000        1672
# 5                         NUCLEAR ENGINEERING   65000         400
# 6                           ACTUARIAL SCIENCE   62000         308
# 7                  ASTRONOMY AND ASTROPHYSICS   62000          33
# 8                      MECHANICAL ENGINEERING   60000        4650
# 9                      ELECTRICAL ENGINEERING   60000        3895
# 10                       COMPUTER ENGINEERING   60000        2275
# 11                      AEROSPACE ENGINEERING   60000         794
# 12                     BIOMEDICAL ENGINEERING   60000        1019
# 13                          MATERIALS SCIENCE   60000          78
# 14  ENGINEERING MECHANICS PHYSICS AND SCIENCE   58000          23
# 15                     BIOLOGICAL ENGINEERING   57100         589
# 16   INDUSTRIAL AND MANUFACTURING ENGINEERING   57000         699
# 17                        GENERAL ENGINEERING   56000        2859
# 18                  ARCHITECTURAL ENGINEERING   54000         170
# 19                            COURT REPORTING   54000          11

# %%
# Engineering where sharewomen >= 0.5 , unemployment_rate < 0.051

e_sh_un = '''SELECT Major,Major_Category, ShareWomen,Unemployment_rate FROM recent_grads
             WHERE (Major_Category = 'Engineering') AND (ShareWomen >= 0.5 OR Unemployment_rate < 0.051);'''

run_query(e_sh_un)
# Out:
#                                          Major Major_category  ShareWomen  \
# 0                        PETROLEUM ENGINEERING    Engineering    0.120564
# 1                    METALLURGICAL ENGINEERING    Engineering    0.153037
# 2    NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering    0.107313
# 3                            MATERIALS SCIENCE    Engineering    0.310820
# 4    ENGINEERING MECHANICS PHYSICS AND SCIENCE    Engineering    0.183985
# 5     INDUSTRIAL AND MANUFACTURING ENGINEERING    Engineering    0.343473
# 6  MATERIALS ENGINEERING AND MATERIALS SCIENCE    Engineering    0.292607
# 7                    ENVIRONMENTAL ENGINEERING    Engineering    0.558548
# 8           INDUSTRIAL PRODUCTION TECHNOLOGIES    Engineering    0.750473
# 9        ENGINEERING AND INDUSTRIAL MANAGEMENT    Engineering    0.174123
#
#    Unemployment_rate
# 0           0.018381
# 1           0.024096
# 2           0.050125
# 3           0.023043
# 4           0.006334
# 5           0.042876
# 6           0.027789
# 7           0.093589
# 8           0.028308
# 9           0.033652

# %%
# Order by Sharewomen in Descending order
desc_sw = '''SELECT Major,ShareWomen,Unemployment_rate from recent_grads
             WHERE ShareWomen > 0.3 AND Unemployment_rate < 0.1
             ORDER BY ShareWomen DESC'''

run_query(desc_sw)
# Out:
#                                                  Major  ShareWomen  \
# 0                            EARLY CHILDHOOD EDUCATION    0.967998
# 1                     MATHEMATICS AND COMPUTER SCIENCE    0.927807
# 2                                 ELEMENTARY EDUCATION    0.923745
# 3                                      ANIMAL SCIENCES    0.910933
# 4                                           PHYSIOLOGY    0.906677
# 5                             MISCELLANEOUS PSYCHOLOGY    0.905590
# 6            HUMAN SERVICES AND COMMUNITY ORGANIZATION    0.904075
# 7                                              NURSING    0.896019
# 8                                          GEOSCIENCES    0.881294
# 9                                           MASS MEDIA    0.877228
# 10                 COGNITIVE SCIENCE AND BIOPSYCHOLOGY    0.854523
# 11                           ART HISTORY AND CRITICISM    0.845934
# 12                              EDUCATIONAL PSYCHOLOGY    0.817099
# 13                                   GENERAL EDUCATION    0.812877
# 14                                         SOCIAL WORK    0.810704
# 15                  TEACHER EDUCATION: MULTIPLE LEVELS    0.798920
# 16                               COUNSELING PSYCHOLOGY    0.798746
# 17                       MATHEMATICS TEACHER EDUCATION    0.792095
# 18                                          PSYCHOLOGY    0.779933
# 19                 GENERAL MEDICAL AND HEALTH SERVICES    0.774577
# 20          HEALTH AND MEDICAL ADMINISTRATIVE SERVICES    0.770901
# 21                                        SOIL SCIENCE    0.764427
# 22                AREA ETHNIC AND CIVILIZATION STUDIES    0.758060
# 23                                 APPLIED MATHEMATICS    0.753927
# 24                        FAMILY AND CONSUMER SCIENCES    0.752144
# 25                  INDUSTRIAL PRODUCTION TECHNOLOGIES    0.750473
# 26                                   SOCIAL PSYCHOLOGY    0.747561
# 27                                          HUMANITIES    0.745662
# 28                              HOSPITALITY MANAGEMENT    0.733992
# 29         SOCIAL SCIENCE OR HISTORY TEACHER EDUCATION    0.733968
# ..                                                 ...         ...
# 91                                             PHYSICS    0.448099
# 92                                               MUSIC    0.444582
# 93                          ASTRONOMY AND ASTROPHYSICS    0.441356
# 94                              ELECTRICAL ENGINEERING    0.437847
# 95                    MEDICAL TECHNOLOGIES TECHNICIANS    0.434298
# 96   NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...    0.430537
# 97                                   PHYSICAL SCIENCES    0.426924
# 98              SCIENCE AND COMPUTER TEACHER EDUCATION    0.423209
# 99                                    GENERAL BUSINESS    0.417925
# 100                   PHILOSOPHY AND RELIGIOUS STUDIES    0.416810
# 101                            MISCELLANEOUS FINE ARTS    0.410180
# 102             COSMETOLOGY SERVICES AND CULINARY ARTS    0.383719
# 103                   MARKETING AND MARKETING RESEARCH    0.382900
# 104        MECHANICAL ENGINEERING RELATED TECHNOLOGIES    0.377437
# 105                  COMMERCIAL ART AND GRAPHIC DESIGN    0.374356
# 106                            SPECIAL NEEDS EDUCATION    0.366177
# 107                                            FINANCE    0.355469
# 108                          ARCHITECTURAL ENGINEERING    0.350442
# 109           INDUSTRIAL AND MANUFACTURING ENGINEERING    0.343473
# 110                              CONSTRUCTION SERVICES    0.342229
# 111                               CHEMICAL ENGINEERING    0.341631
# 112                                          ECONOMICS    0.340825
# 113                    ENGLISH LANGUAGE AND LITERATURE    0.339671
# 114                  ELECTRICAL ENGINEERING TECHNOLOGY    0.325092
# 115             GEOLOGICAL AND GEOPHYSICAL ENGINEERING    0.324838
# 116                OPERATIONS LOGISTICS AND E-COMMERCE    0.322222
# 117           TRANSPORTATION SCIENCES AND TECHNOLOGIES    0.321296
# 118                             BIOLOGICAL ENGINEERING    0.320784
# 119                                  MATERIALS SCIENCE    0.310820
# 120                                     COMMUNICATIONS    0.305109
#
#      Unemployment_rate
# 0             0.040105
# 1             0.000000
# 2             0.046586
# 3             0.050862
# 4             0.069163
# 5             0.051908
# 6             0.037819
# 7             0.044863
# 8             0.024374
# 9             0.089837
# 10            0.075236
# 11            0.060298
# 12            0.065112
# 13            0.057360
# 14            0.068828
# 15            0.036546
# 16            0.053621
# 17            0.016203
# 18            0.083811
# 19            0.082102
# 20            0.089626
# 21            0.000000
# 22            0.063429
# 23            0.090823
# 24            0.067128
# 25            0.028308
# 26            0.029650
# 27            0.068584
# 28            0.061169
# 29            0.054083
# ..                 ...
# 91            0.048224
# 92            0.075960
# 93            0.021167
# 94            0.059174
# 95            0.036983
# 96            0.071540
# 97            0.035354
# 98            0.047264
# 99            0.072861
# 100           0.096052
# 101           0.089375
# 102           0.055677
# 103           0.061215
# 104           0.056357
# 105           0.096798
# 106           0.041508
# 107           0.060686
# 108           0.061931
# 109           0.042876
# 110           0.060023
# 111           0.061098
# 112           0.099092
# 113           0.087724
# 114           0.087557
# 115           0.075038
# 116           0.047859
# 117           0.072725
# 118           0.087143
# 119           0.023043
# 120           0.075177
#
# [121 rows x 3 columns]

# %%
# Engineering or Physical Science
eng_ps = '''SELECT Major_category,Major,Unemployment_rate FROM recent_grads
            WHERE (Major_category = 'Engineering' OR Major_Category = 'Physical Sciences')
            ORDER BY Unemployment_rate ASC'''

run_query(eng_ps)
# Out:
#        Major_category                                              Major  \
# 0         Engineering          ENGINEERING MECHANICS PHYSICS AND SCIENCE
#
# 34           0.092084
# 35           0.093589
# 36           0.113332
# 37           0.117241
# 38           0.177226

# %%
# COUNT
count = '''SELECT COUNT(Major) FROM recent_grads WHERE ShareWomen > 0.5'''

run_query(count)
# Out:
#    COUNT(Major)
# 0            97

# %%
# ENgineering Major with lowest median salary.
eng_min = '''SELECT Major,Major_category,MIN(Median) FROM recent_grads
             WHERE Major_category = 'Engineering';'''

run_query(eng_min)
# Out:
#           Major Major_category  MIN(Median)
# 0  ARCHITECTURE    Engineering        40000

# %%
# Aggregating 
avg = '''SELECT AVG(Total), MIN(Men), MAX(Women) FROM recent_grads;'''

run_query(avg)
# Out:
#      AVG(Total)  MIN(Men)  MAX(Women)
# 0  39167.716763       119      307087

# %%
# number of roles, unemployment rate.
nroles = '''SELECT COUNT(Major) 'Number Of Majors', MAX(Unemployment_rate) 'Highest Unemployment Rate' FROM recent_grads;'''

run_query(nroles)
# Out:
#    Number Of Majors  Highest Unemployment Rate
# 0               173                   0.177226

# %%
# UNIQUE values usiing DISTINCT()
unique = '''SELECT COUNT(DISTINCT(Major)) 'unique_major',COUNT(DISTINCT(Major_category)) 'unique_major_category',COUNT(DISTINCT(Major_code)) 'unique_major_code' FROM recent_grads;'''

run_query(unique)
# Out:
#    unique_major  unique_major_category  unique_major_code
# 0           173                     16                173

# %%
# diff btw 25th and 75th percentile.
ptiles = '''SELECT Major,Major_category, (P75th - p25th) Quartile_Spread FROM recent_grads
            ORDER BY Quartile_Spread ASC
            LIMIT 20;
            '''

run_query(ptiles)
# Out:
#                                          Major  \
# 0                        MILITARY TECHNOLOGIES
# 1                    SCHOOL STUDENT COUNSELING
# 2                              LIBRARY SCIENCE
# 3                              COURT REPORTING
# 4                                 PHARMACOLOGY
# 5   EDUCATIONAL ADMINISTRATION AND SUPERVISION
# 6                        COUNSELING PSYCHOLOGY
# 7                      SPECIAL NEEDS EDUCATION
# 8                MATHEMATICS TEACHER EDUCATION
# 9                                  SOCIAL WORK
# 10                      EDUCATIONAL PSYCHOLOGY
# 11                                    GENETICS
# 12                           SOCIAL PSYCHOLOGY
# 13      SCIENCE AND COMPUTER TEACHER EDUCATION
# 14   HUMAN SERVICES AND COMMUNITY ORGANIZATION
# 15                       UNITED STATES HISTORY
# 16                 SECONDARY TEACHER EDUCATION
# 17          TEACHER EDUCATION: MULTIPLE LEVELS
# 18                   ENVIRONMENTAL ENGINEERING
# 19            MEDICAL TECHNOLOGIES TECHNICIANS
#
#                          Major_category  Quartile_Spread
# 0   Industrial Arts & Consumer Services                0
# 1                             Education             2000
# 2                             Education             2000
# 3                   Law & Public Policy             4000
# 4                Biology & Life Science             5000
# 5                             Education             6000
# 6              Psychology & Social Work             6800
# 7                             Education            10000
# 8                             Education            10000
# 9              Psychology & Social Work            10000
# 10             Psychology & Social Work            10000
# 11               Biology & Life Science            11000
# 12             Psychology & Social Work            11000
# 13                            Education            11000
# 14             Psychology & Social Work            11000
# 15            Humanities & Liberal Arts            12000
# 16                            Education            13000
# 17                            Education            13000
# 18                          Engineering            14000
# 19                               Health            14000

# %%
# Using GROUPBY 
group = '''SELECT Major_category, AVG(ShareWomen) FROM recent_grads
           GROUP BY Major_category;'''

run_query(group)
# Out:
#                          Major_category  AVG(ShareWomen)
# 0       Agriculture & Natural Resources         0.617938
# 1                                  Arts         0.561851
# 2                Biology & Life Science         0.584518
# 3                              Business         0.405063
# 4           Communications & Journalism         0.643835
# 5               Computers & Mathematics         0.512752
# 6                             Education         0.674986
# 7                           Engineering         0.257158
# 8                                Health         0.616857
# 9             Humanities & Liberal Arts         0.676193
# 10  Industrial Arts & Consumer Services         0.449351
# 11                    Interdisciplinary         0.495397
# 12                  Law & Public Policy         0.335990
# 13                    Physical Sciences         0.508749
# 14             Psychology & Social Work         0.777763
# 15                       Social Science         0.539067

# %%
# Percentage Employed.
percent_employed = '''SELECT Major_category,((AVG(Employed)/AVG(Total)) * 100)Share_Employed FROM recent_grads
                      GROUP BY Major_category;'''

run_query(percent_employed)
# Out:
#                          Major_category  Share_Employed
# 0       Agriculture & Natural Resources       83.698628
# 1                                  Arts       80.674824
# 2                Biology & Life Science       66.715654
# 3                              Business       83.596596
# 4           Communications & Journalism       84.222913
# 5               Computers & Mathematics       79.561082
# 6                             Education       85.819015
# 7                           Engineering       78.196669
# 8                                Health       80.337413
# 9             Humanities & Liberal Arts       76.263827
# 10  Industrial Arts & Consumer Services       82.267007
# 11                    Interdisciplinary       79.871503
# 12                  Law & Public Policy       80.839945
# 13                    Physical Sciences       75.065641
# 14             Psychology & Social Work       79.072446
# 15                       Social Science       75.758256

# %%
# Filtering GROUP BY statement with HAVING
having = '''SELECT Major_category, AVG(low_wage_jobs)/AVG(Total) Share_Low_Wage FROM recent_grads
            GROUP BY Major_category
            HAVING Share_Low_Wage > 0.1;'''

run_query(having)
# Out:
#                         Major_category  Share_Low_Wage
# 0                                 Arts        0.168331
# 1          Communications & Journalism        0.126324
# 2            Humanities & Liberal Arts        0.132087
# 3  Industrial Arts & Consumer Services        0.115713
# 4                  Law & Public Policy        0.115685
# 5             Psychology & Social Work        0.116934
# 6                       Social Science        0.102233

# %%
# ROUNDING decimals
rounding = '''SELECT ROUND(ShareWomen, 4), Major_category FROM recent_grads
              LIMIT 10;'''

run_query(rounding)
# Out:
#    ROUND(ShareWomen, 4)     Major_category
# 0                0.1206        Engineering
# 1                0.1019        Engineering
# 2                0.1530        Engineering
# 3                0.1073        Engineering
# 4                0.3416        Engineering
# 5                0.1450        Engineering
# 6                0.5357           Business
# 7                0.4414  Physical Sciences
# 8                0.1398        Engineering
# 9                0.4378        Engineering

# %%
# ROUNDING MORE COMPLEX
round_2 = '''SELECT Major_category, ROUND(AVG(college_jobs)/AVG(Total), 3)share_degree_job FROM recent_grads
             GROUP BY Major_category
             HAVING share_degree_job < 0.3;'''

run_query(round_2)
# Out:
#                         Major_category  share_degree_job
# 0      Agriculture & Natural Resources             0.248
# 1                                 Arts             0.265
# 2                             Business             0.114
# 3          Communications & Journalism             0.220
# 4            Humanities & Liberal Arts             0.270
# 5  Industrial Arts & Consumer Services             0.249
# 6                  Law & Public Policy             0.163
# 7                       Social Science             0.215

# %%
# CASTING 
cast = '''SELECT Major_category,(CAST(Women AS FLOAT)/CAST(Total AS FLOAT)) SW FROM recent_grads
          GROUP BY Major_category
          ORDER BY SW;'''

run_query(cast)
# Out:
#                          Major_category        SW
# 0                   Law & Public Policy  0.002951
# 1                           Engineering  0.113152
# 2                                  Arts  0.275868
# 3                              Business  0.279172
# 4                     Physical Sciences  0.468217
# 5           Communications & Journalism  0.506020
# 6                Biology & Life Science  0.637293
# 7                                Health  0.717574
# 8              Psychology & Social Work  0.798746
# 9                     Interdisciplinary  0.800911
# 10                            Education  0.877960
# 11              Computers & Mathematics  0.906349
# 12  Industrial Arts & Consumer Services  1.102854
# 13            Humanities & Liberal Arts  1.520023
# 14                       Social Science  4.867879
# 15      Agriculture & Natural Resources  8.214382

# %%
# USING SUB QUERIES
sub = '''SELECT Major, Unemployment_rate FROM recent_grads
         WHERE Unemployment_rate < (SELECT AVG(Unemployment_rate) from recent_grads)
         ORDER BY Unemployment_rate ASC;'''

run_query(sub)
# Out:
#                                                 Major  Unemployment_rate
# 0                    MATHEMATICS AND COMPUTER SCIENCE           0.000000
# 1                                              BOTANY           0.000000
# 2                                        SOIL SCIENCE           0.000000
# 3          EDUCATIONAL ADMINISTRATION AND SUPERVISION           0.000000
# 4           ENGINEERING MECHANICS PHYSICS AND SCIENCE           0.006334
# 5                                     COURT REPORTING           0.011690
# 6                       MATHEMATICS TEACHER EDUCATION           0.016203
# 7                               PETROLEUM ENGINEERING           0.018381
# 8                                 GENERAL AGRICULTURE           0.019642
# 9                          ASTRONOMY AND ASTROPHYSICS           0.021167
# 10               ATMOSPHERIC SCIENCES AND METEOROLOGY           0.022229
# 11                                  MATERIALS SCIENCE           0.023043
# 12                          METALLURGICAL ENGINEERING           0.024096
# 13                                        GEOSCIENCES           0.024374
# 14        MATERIALS ENGINEERING AND MATERIALS SCIENCE           0.027789
# 15                 INDUSTRIAL PRODUCTION TECHNOLOGIES           0.028308
# 16  ELECTRICAL, MECHANICAL, AND PRECISION TECHNOLO...           0.029480
# 17                                  SOCIAL PSYCHOLOGY           0.029650
# 18              ENGINEERING AND INDUSTRIAL MANAGEMENT           0.033652
# 19                                           GENETICS           0.034118
# 20                                  PHYSICAL SCIENCES           0.035354
# 21                 TEACHER EDUCATION: MULTIPLE LEVELS           0.036546
# 22                   MEDICAL TECHNOLOGIES TECHNICIANS           0.036983
# 23          HUMAN SERVICES AND COMMUNITY ORGANIZATION           0.037819
# 24                            ART AND MUSIC EDUCATION           0.038638
# 25                          EARLY CHILDHOOD EDUCATION           0.040105
# 26                            SPECIAL NEEDS EDUCATION           0.041508
# 27                         MEDICAL ASSISTING SERVICES           0.042507
# 28           INDUSTRIAL AND MANUFACTURING ENGINEERING           0.042876
# 29                                            NURSING           0.044863
# ..                                                ...                ...
# 57                                       OCEANOGRAPHY           0.056995
# 58                             MECHANICAL ENGINEERING           0.057342
# 59                                  GENERAL EDUCATION           0.057360
# 60      MANAGEMENT INFORMATION SYSTEMS AND STATISTICS           0.058240
# 61                              MISCELLANEOUS BIOLOGY           0.058545
# 62                             ELECTRICAL ENGINEERING           0.059174
# 63                            MISCELLANEOUS EDUCATION           0.059212
# 64           HUMAN RESOURCES AND PERSONNEL MANAGEMENT           0.059570
# 65                          MISCELLANEOUS AGRICULTURE           0.059767
# 66                      TREATMENT THERAPY PROFESSIONS           0.059821
# 67                                GENERAL ENGINEERING           0.059824
# 68                              CONSTRUCTION SERVICES           0.060023
# 69                          ART HISTORY AND CRITICISM           0.060298
# 70                                            FINANCE           0.060686
# 71                               INFORMATION SCIENCES           0.060741
# 72                               CHEMICAL ENGINEERING           0.061098
# 73                             HOSPITALITY MANAGEMENT           0.061169
# 74                   MARKETING AND MARKETING RESEARCH           0.061215
# 75                          ARCHITECTURAL ENGINEERING           0.061931
# 76                   THEOLOGY AND RELIGIOUS VOCATIONS           0.062628
# 77                                   COMPUTER SCIENCE           0.063173
# 78               AREA ETHNIC AND CIVILIZATION STUDIES           0.063429
# 79                             EDUCATIONAL PSYCHOLOGY           0.065112
# 80                              AEROSPACE ENGINEERING           0.065162
# 81                               COMPUTER ENGINEERING           0.065409
# 82                       NATURAL RESOURCES MANAGEMENT           0.066619
# 83                                       MICROBIOLOGY           0.066776
# 84                       FAMILY AND CONSUMER SCIENCES           0.067128
# 85                   ADVERTISING AND PUBLIC RELATIONS           0.067961
# 86                                         HUMANITIES           0.068584
#
# [87 rows x 2 columns]

# %%
# SUBQUERY EXTENDED
sub_2 = '''SELECT CAST(COUNT(*) AS FLOAT)/ CAST((SELECT COUNT(*) FROM recent_grads) AS FLOAT) proportion_abv_avg FROM recent_grads 
           WHERE ShareWomen > (SELECT AVG(ShareWomen) FROM recent_grads)'''

run_query(sub_2)
# Out:
#    proportion_abv_avg
# 0            0.526012

# %%
# 
m = '''
       SELECT Major_category FROM recent_grads
       GROUP BY Major_category
       ORDER BY SUM(Total) DESC
       LIMIT 5;'''

run_query(m)
# Out:
#               Major_category
# 0                   Business
# 1  Humanities & Liberal Arts
# 2                  Education
# 3                Engineering
# 4             Social Science

# %%
mm = '''SELECT Major, Major_category FROM recent_grads 
        WHERE Major_category IN
        (SELECT Major_category FROM recent_grads
        GROUP BY Major_category
        ORDER BY SUM(Total) DESC
        LIMIT 5);
       '''
run_query(mm)
# Out:
#                                                 Major  \
# 0                               PETROLEUM ENGINEERING
# 1                      MINING AND MINERAL ENGINEERING
# 2                           METALLURGICAL ENGINEERING
# 3           NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                                CHEMICAL ENGINEERING
# 5                                 NUCLEAR ENGINEERING
# 6                                   ACTUARIAL SCIENCE
# 7                              MECHANICAL ENGINEERING
# 8                              ELECTRICAL ENGINEERING
# 9                                COMPUTER ENGINEERING
# 10                              AEROSPACE ENGINEERING
# 11                             BIOMEDICAL ENGINEERING
# 12                                  MATERIALS SCIENCE
# 13          ENGINEERING MECHANICS PHYSICS AND SCIENCE
#
# 62                  Education
# 63             Social Science
# 64                  Education
# 65  Humanities & Liberal Arts
# 66                  Education
# 67  Humanities & Liberal Arts
# 68                  Education
# 69  Humanities & Liberal Arts
# 70             Social Science
# 71                  Education
# 72                  Education
# 73  Humanities & Liberal Arts
# 74                  Education
# 75  Humanities & Liberal Arts
# 76  Humanities & Liberal Arts
# 77  Humanities & Liberal Arts
# 78                  Education
# 79  Humanities & Liberal Arts
# 80  Humanities & Liberal Arts
# 81                  Education
#
# [82 rows x 2 columns]

# %% [markdown]
# > Lets say we are interested in understanding the ratio of the sample_size column to the total column.
#  >* Computing this ratio for every major.
#  >* Understanding which majors are above the average for this ratio.
#  >* Understanding how many majors are above the average for this ratio.

# %%
# Average ratio for all the majors
avg_sub = '''SELECT AVG(CAST(Sample_size AS FLOAT) / CAST(Total AS FLOAT)) avg_ratio FROM recent_grads'''

run_query(avg_sub)
# Out:
#    avg_ratio
# 0   0.009086

# %%
com = '''SELECT Major,Major_category, (CAST(Sample_size AS FLOAT) / CAST(Total AS FLOAT)) Ratio FROM recent_grads
         WHERE Ratio >(SELECT AVG(CAST(Sample_size AS FLOAT)/CAST(Total AS FLOAT))avg_ratio FROM recent_grads)'''

run_query(com)
# Out:
#                                                 Major  \
# 0                               PETROLEUM ENGINEERING
# 1                      MINING AND MINERAL ENGINEERING
# 2           NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 3                                   ACTUARIAL SCIENCE
# 4                              MECHANICAL ENGINEERING
# 5                                COMPUTER ENGINEERING
# 6                               AEROSPACE ENGINEERING
# 7            INDUSTRIAL AND MANUFACTURING ENGINEERING
# 8                           ARCHITECTURAL ENGINEERING
# 9                                     COURT REPORTING
# 10                                   COMPUTER SCIENCE
# 11      MANAGEMENT INFORMATION SYSTEMS AND STATISTICS
# 12                                  CIVIL ENGINEERING
# 13                              CONSTRUCTION SERVICES
# 14                OPERATIONS LOGISTICS AND E-COMMERCE
# 15                          MISCELLANEOUS ENGINEERING
# 16                                      PUBLIC POLICY
# 17                           ENGINEERING TECHNOLOGIES
# 18                                            NURSING
# 19                                            FINANCE
# 20                                          ECONOMICS
# 21                                 BUSINESS ECONOMICS
# 22                 INDUSTRIAL PRODUCTION TECHNOLOGIES
# 23  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 24                                         ACCOUNTING
# 25                   COMPUTER AND INFORMATION SYSTEMS
# 26                   MEDICAL TECHNOLOGIES TECHNICIANS
# 27                               INFORMATION SCIENCES
# 28                                APPLIED MATHEMATICS
# 29                                       OCEANOGRAPHY
# ..                                                ...
# 52                  COMMERCIAL ART AND GRAPHIC DESIGN
# 53                                         JOURNALISM
# 54                   ADVERTISING AND PUBLIC RELATIONS
# 55                                        CRIMINOLOGY
# 56         HEALTH AND MEDICAL ADMINISTRATIVE SERVICES
# 57                         COMMUNICATION TECHNOLOGIES
# 58           TRANSPORTATION SCIENCES AND TECHNOLOGIES
# 59                       NATURAL RESOURCES MANAGEMENT
# 60                    MULTI/INTERDISCIPLINARY STUDIES
# 61                                           FORESTRY
# 62                                         MASS MEDIA
